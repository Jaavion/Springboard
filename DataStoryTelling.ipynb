# %%
import pandas as pd

# %%
weather_events = pd.read_csv('US_WeatherEvents_2016-2019.csv')

# %%
weather_events
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 0              W-1  Snow     Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1              W-2  Snow     Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2              W-3  Snow     Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3              W-4  Snow     Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4              W-5  Snow     Light  2016-01-08 13:54:00  2016-01-08 15:54:00
# 5              W-6  Snow     Light  2016-01-08 16:14:00  2016-01-08 17:34:00
# 6              W-7   Fog    Severe  2016-01-09 12:54:00  2016-01-09 15:34:00
# 7              W-8  Snow     Light  2016-01-09 15:34:00  2016-01-09 16:14:00
# 8              W-9   Fog    Severe  2016-01-09 16:14:00  2016-01-09 16:34:00
# 9             W-10  Snow     Light  2016-01-09 16:34:00  2016-01-09 16:54:00
# 10            W-11  Cold    Severe  2016-01-09 16:54:00  2016-01-09 20:34:00
# ...

# %%
weather_events.shape
# Out:
# (5059833, 13)

# %%
weather_events.Type.value_counts()
# Out:
# Rain             3067581
# Fog              1068653
# Snow              679472
# Cold              141626
# Precipitation      67299
# Storm              32688
# Hail                2514
# Name: Type, dtype: int64

# %%
Rain = weather_events['Type'] == 'Rain'

# %%
weather_events['State'].value_counts()
# Out:
# TX    353317
# MN    277545
# MI    247450
# FL    219381
# NC    203226
# CA    201836
# WI    194215
# IL    166846
# GA    156380
# VA    154128
# IA    147050
# LA    134113
# WA    126532
# CO    126141
# NY    125085
# OH    123464
# SC    120677
# PA    119476
# WY    114007
# AL    110198
# OK    105403
# ND     99395
# OR     98528
# NE     89452
# IN     89437
# AR     88445
# MS     81101
# MO     76281
# KY     74517
# KS     71991
# MA     70971
# MT     63843
# WV     58354
# ID     57329
# SD     56715
# ME     54273
# NM     53292
# NJ     45068
# MD     44190
# NH     43976
# TN     41970
# AZ     37998
# VT     35411
# UT     28204
# CT     26598
# NV     21710
# RI     14786
# DE      9528
# Name: State, dtype: int64

# %%
CA = weather_events['State'] == 'CA'

# %%
CA = weather_events[CA]

# %%
Los_Angeles = CA['County'] == 'Los Angeles'

# %%
Los_Angeles = CA[Los_Angeles]

# %%
Los_Angeles.ZipCode.value_counts()
# Out:
# 93243.0    2044
# 90007.0    1714
# 90250.0    1714
# 90045.0    1371
# 90807.0    1356
# 91381.0    1315
# 90405.0    1265
# 91406.0    1230
# 91505.0    1170
# 93591.0     876
# 91731.0     654
# 93536.0     634
# 93550.0     632
# 91750.0     530
# 90505.0     491
# 91331.0     470
# Name: ZipCode, dtype: int64

# %%
Los_Angeles.dtypes
# Out:
# EventId            object
# Type               object
# Severity           object
# StartTime(UTC)     object
# EndTime(UTC)       object
# TimeZone           object
# AirportCode        object
# LocationLat       float64
# LocationLng       float64
# City               object
# County             object
# State              object
# ZipCode           float64
# dtype: object

# %%
Los_Angeles
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 397756    W-397809  Rain     Light  2016-01-05 15:53:00  2016-01-05 16:44:00
# 397757    W-397810  Rain  Moderate  2016-01-05 16:44:00  2016-01-05 17:01:00
# 397758    W-397811  Rain     Light  2016-01-05 17:01:00  2016-01-05 17:19:00
# 397759    W-397812  Rain  Moderate  2016-01-05 17:19:00  2016-01-05 18:05:00
# 397760    W-397813  Rain     Light  2016-01-05 18:05:00  2016-01-05 18:25:00
# 397761    W-397814  Rain  Moderate  2016-01-05 18:25:00  2016-01-05 19:42:00
# 397762    W-397815  Rain     Light  2016-01-05 19:42:00  2016-01-05 19:50:00
# 397763    W-397816  Rain  Moderate  2016-01-05 19:50:00  2016-01-05 21:00:00
# 397764    W-397817  Rain     Light  2016-01-05 21:00:00  2016-01-05 23:09:00
# 397765    W-397818  Rain     Light  2016-01-06 18:53:00  2016-01-06 19:31:00
# 397766    W-397819  Rain  Moderate  2016-01-06 19:31:00  2016-01-06 20:15:00
# ...

# %%
Los_Angeles['StartTime(UTC)'] = pd.to_datetime(Los_Angeles['StartTime(UTC)'])
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Los_Angeles['EndTime(UTC)'] = pd.to_datetime(Los_Angeles['EndTime(UTC)'])
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Los_Angeles.dtypes
# Out:
# EventId                   object
# Type                      object
# Severity                  object
# StartTime(UTC)    datetime64[ns]
# EndTime(UTC)      datetime64[ns]
# TimeZone                  object
# AirportCode               object
# LocationLat              float64
# LocationLng              float64
# City                      object
# County                    object
# State                     object
# ZipCode                  float64
# dtype: object

# %%
Rain
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 51            W-52  Rain     Light  2016-02-19 04:34:00  2016-02-19 05:14:00
# 82            W-83  Rain     Light  2016-04-09 20:55:00  2016-04-09 21:15:00
# 83            W-84  Rain     Light  2016-04-09 22:55:00  2016-04-10 00:15:00
# 84            W-85  Rain     Light  2016-04-11 06:15:00  2016-04-11 06:35:00
# 85            W-86  Rain     Light  2016-04-11 21:55:00  2016-04-11 22:15:00
# 86            W-87  Rain     Light  2016-04-12 03:55:00  2016-04-12 04:55:00
# 87            W-88  Rain     Light  2016-04-12 23:15:00  2016-04-12 23:35:00
# 88            W-89  Rain     Light  2016-04-12 23:55:00  2016-04-13 00:55:00
# 89            W-90  Rain     Light  2016-04-13 02:35:00  2016-04-13 02:55:00
# 90            W-91  Rain     Light  2016-04-15 21:55:00  2016-04-15 22:15:00
# 91            W-92  Rain     Light  2016-04-15 22:55:00  2016-04-15 23:15:00
# ...

# %% [raw]
# Rain.sort_values("Type", ascending=False)

# %%
Rain = weather_events[Rain]

# %%
import seaborn as sns
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(14,8.27)})
ax = sns.countplot(x="State",data=Rain)

# %%
texas_rain =
# Out:
#   File "<ipython-input-69-35c8172fd093>", line 1
#     Texas = weather_events['State'] == 'Texas' && weather_events['Type'] == 'Rain'
#                                                 ^
# SyntaxError: invalid syntax

# %%
Rain['Severity'].value_counts()
# Out:
# Light       2540233
# Moderate     410673
# Heavy        116675
# Name: Severity, dtype: int64

# %%
Severity = Rain['Severity'] == 'Heavy'

# %%
Light_Rain = Rain[Severity]

# %%
import seaborn as sns
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(14,8.27)})
ax = sns.countplot(x="State",data=Light_Rain.dropna())

# %%
import seaborn as sns
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(14,8.27)})
ax = sns.countplot(x="Severity",data=Los_Angeles)

# %%
Los_Angeles['Type'].value_counts()
# Out:
# Fog              8664
# Rain             7290
# Cold              810
# Snow              389
# Storm             282
# Precipitation      30
# Hail                1
# Name: Type, dtype: int64

# %%
Los_Angeles_Snow = Los_Angeles['Type'] == 'Snow'

# %%
Los_Angeles_Snow = Los_Angeles[Los_Angeles_Snow]

# %%
Los_Angeles_Snow['StarTime(UTC)'] = pd.DatetimeIndex(Los_Angeles_Snow['StartTime(UTC)']).year
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Los_Angeles_Snow.head()
# Out:
#          EventId  Type  Severity      StartTime(UTC)        EndTime(UTC)  \
# 873570  W-873700  Snow  Moderate 2016-01-31 23:35:00 2016-01-31 23:53:00
# 873573  W-873703  Snow     Light 2016-02-01 04:53:00 2016-02-01 05:53:00
# 873726  W-873856  Snow     Heavy 2017-01-23 18:27:00 2017-01-23 18:45:00
# 873994  W-874124  Snow  Moderate 2019-02-06 01:48:00 2019-02-06 02:03:00
# 873995  W-874125  Snow     Light 2019-02-06 02:03:00 2019-02-06 02:23:00
#
#           TimeZone AirportCode  LocationLat  LocationLng      City  \
# 873570  US/Pacific        KPMD      34.6294    -118.0831  Palmdale
# 873573  US/Pacific        KPMD      34.6294    -118.0831  Palmdale
# 873726  US/Pacific        KPMD      34.6294    -118.0831  Palmdale
# 873994  US/Pacific        KPMD      34.6294    -118.0831  Palmdale
# 873995  US/Pacific        KPMD      34.6294    -118.0831  Palmdale
#
#              County State  ZipCode  StarTime(UTC)
# 873570  Los Angeles    CA  93550.0           2016
# ...

# %%
Time = []
for i in str(Los_Angeles_Snow['StartTime(UTC)']):
    Time.append(i)

# %%
Los_Angeles_Snow['StartTime(UTC)'] = Los_Angeles_Snow['StartTime(UTC)'].apply(lambda t: t.strftime('%Y-%m-%d %H:%M'))
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Los_Angeles_Snow['Year'] = pd.DatetimeIndex(Los_Angeles_Snow['StartTime(UTC)']).year
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Los_Angeles['Severity'] = Los_Angeles_Snow.Severity.str.replace('Light', '1')
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Los_Angeles['Severity'] = Los_Angeles_Snow.Severity.str.replace('Heavy', '3')
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Los_Angeles
# Out:
#            EventId  Type Severity      StartTime(UTC)        EndTime(UTC)  \
# 397756    W-397809  Rain      NaN 2016-01-05 15:53:00 2016-01-05 16:44:00
# 397757    W-397810  Rain      NaN 2016-01-05 16:44:00 2016-01-05 17:01:00
# 397758    W-397811  Rain      NaN 2016-01-05 17:01:00 2016-01-05 17:19:00
# 397759    W-397812  Rain      NaN 2016-01-05 17:19:00 2016-01-05 18:05:00
# 397760    W-397813  Rain      NaN 2016-01-05 18:05:00 2016-01-05 18:25:00
# 397761    W-397814  Rain      NaN 2016-01-05 18:25:00 2016-01-05 19:42:00
# 397762    W-397815  Rain      NaN 2016-01-05 19:42:00 2016-01-05 19:50:00
# 397763    W-397816  Rain      NaN 2016-01-05 19:50:00 2016-01-05 21:00:00
# 397764    W-397817  Rain      NaN 2016-01-05 21:00:00 2016-01-05 23:09:00
# 397765    W-397818  Rain      NaN 2016-01-06 18:53:00 2016-01-06 19:31:00
# 397766    W-397819  Rain      NaN 2016-01-06 19:31:00 2016-01-06 20:15:00
# 397767    W-397820  Rain      NaN 2016-01-06 20:15:00 2016-01-06 21:53:00
# ...

# %%
Los_Angeles_Snow.replace(to_replace ="", 
                 value ="Omega Warrior")

# %%
# Out:
#            EventId  Type  Severity      StartTime(UTC)        EndTime(UTC)  \
# 873570    W-873700  Snow  Moderate 2016-01-31 23:35:00 2016-01-31 23:53:00
# 873573    W-873703  Snow         1 2016-02-01 04:53:00 2016-02-01 05:53:00
# 873726    W-873856  Snow     Heavy 2017-01-23 18:27:00 2017-01-23 18:45:00
# 873994    W-874124  Snow  Moderate 2019-02-06 01:48:00 2019-02-06 02:03:00
# 873995    W-874125  Snow         1 2019-02-06 02:03:00 2019-02-06 02:23:00
# 874025    W-874155  Snow         1 2019-02-21 21:53:00 2019-02-21 22:17:00
# 874101    W-874231  Snow  Moderate 2019-11-28 15:22:00 2019-11-28 16:35:00
# 874102    W-874232  Snow         1 2019-11-28 16:35:00 2019-11-28 18:53:00
# 874103    W-874233  Snow  Moderate 2019-11-28 18:53:00 2019-11-28 19:02:00
# 874104    W-874234  Snow         1 2019-11-28 19:02:00 2019-11-28 19:26:00
# 874105    W-874235  Snow  Moderate 2019-11-28 19:26:00 2019-11-28 19:53:00
# ...

# %%
Los_Angeles_Snow['StarTime(UTC)'] = pd.DatetimeIndex(Los_Angeles_Snow['StartTime(UTC)']).month
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Los_Angeles_Snow
# Out:
#            EventId  Type  Severity    StartTime(UTC)        EndTime(UTC)  \
# 873570    W-873700  Snow  Moderate  2016-01-31 23:35 2016-01-31 23:53:00
# 873573    W-873703  Snow         1  2016-02-01 04:53 2016-02-01 05:53:00
# 873726    W-873856  Snow     Heavy  2017-01-23 18:27 2017-01-23 18:45:00
# 873994    W-874124  Snow  Moderate  2019-02-06 01:48 2019-02-06 02:03:00
# 873995    W-874125  Snow         1  2019-02-06 02:03 2019-02-06 02:23:00
# 874025    W-874155  Snow         1  2019-02-21 21:53 2019-02-21 22:17:00
# 874101    W-874231  Snow  Moderate  2019-11-28 15:22 2019-11-28 16:35:00
# 874102    W-874232  Snow         1  2019-11-28 16:35 2019-11-28 18:53:00
# 874103    W-874233  Snow  Moderate  2019-11-28 18:53 2019-11-28 19:02:00
# 874104    W-874234  Snow         1  2019-11-28 19:02 2019-11-28 19:26:00
# 874105    W-874235  Snow  Moderate  2019-11-28 19:26 2019-11-28 19:53:00
# 874106    W-874236  Snow     Heavy  2019-11-28 19:53 2019-11-28 20:02:00
# ...

# %%
ax = sns.lineplot(x=, y="Type", data=Los_Angeles_Snow)

# %%
Los_Angeles_Snow = Los_Angeles_Snow.replace(to_replace ="Moderate", 
                 value ="2")

# %%
Los_Angeles_Snow = Los_Angeles_Snow.replace(to_replace ="Heavy", 
                 value ="3")

# %%
Los_Angeles_Snow
# Out:
#            EventId  Type Severity    StartTime(UTC)        EndTime(UTC)  \
# 873570    W-873700  Snow        2  2016-01-31 23:35 2016-01-31 23:53:00
# 873573    W-873703  Snow        1  2016-02-01 04:53 2016-02-01 05:53:00
# 873726    W-873856  Snow        3  2017-01-23 18:27 2017-01-23 18:45:00
# 873994    W-874124  Snow        2  2019-02-06 01:48 2019-02-06 02:03:00
# 873995    W-874125  Snow        1  2019-02-06 02:03 2019-02-06 02:23:00
# 874025    W-874155  Snow        1  2019-02-21 21:53 2019-02-21 22:17:00
# 874101    W-874231  Snow        2  2019-11-28 15:22 2019-11-28 16:35:00
# 874102    W-874232  Snow        1  2019-11-28 16:35 2019-11-28 18:53:00
# 874103    W-874233  Snow        2  2019-11-28 18:53 2019-11-28 19:02:00
# 874104    W-874234  Snow        1  2019-11-28 19:02 2019-11-28 19:26:00
# 874105    W-874235  Snow        2  2019-11-28 19:26 2019-11-28 19:53:00
# 874106    W-874236  Snow        3  2019-11-28 19:53 2019-11-28 20:02:00
# ...

# %%
Los_Angeles_Snow['StarTime(UTC)'] = Los_Angeles_Snow['StarTime(UTC)'].astype(int)

# %%
Los_Angeles_Snow['Severity'] = Los_Angeles_Snow['Severity'].astype(int)

# %%
ax = sns.lineplot(x='StarTime(UTC)', y="Severity", data=Los_Angeles_Snow)
# Out:
# /Users/jaaviondavis/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
Washington = Rain['State'] == 'WA'

# %%
Washington = Rain[Washington]

# %%
Washington.County.value_counts()
# Out:
# Pierce          15330
# King             7408
# Clallam          7059
# Lewis            6245
# Spokane          5870
# San Juan         4321
# Grays Harbor     3816
# Snohomish        3480
# Mason            3408
# Island           3188
# Thurston         2501
# Cowlitz          2268
# Clark            2118
# Whatcom          1933
# Yakima           1779
# Kitsap           1386
# Walla Walla      1228
# Grant            1227
# Whitman          1187
# Kittitas          802
# Klickitat         783
# Okanogan          713
# Franklin          698
# Douglas           654
# Benton            587
# Name: County, dtype: int64

# %%
MA = weather_events[weather_events['State'] == 'MA']

# %%
Concord = MA[MA['City'] == 'Concord']

# %%
Concord.Type.value_counts()
# Out:
# Rain             1752
# Fog               646
# Snow              383
# Cold               40
# Precipitation      19
# Hail                6
# Storm               2
# Name: Type, dtype: int64

# %%
Concord.Type.value_counts().plot(kind='bar');

# %%
weather_events.columns
# Out:
# Index(['EventId', 'Type', 'Severity', 'StartTime(UTC)', 'EndTime(UTC)',
#        'TimeZone', 'AirportCode', 'LocationLat', 'LocationLng', 'City',
#        'County', 'State', 'ZipCode'],
#       dtype='object')

# %%
Seattle = weather_events[weather_events['City'] == 'Seattle']

# %%
Seattle_Rain = Seattle[Seattle['Type'] == 'Rain']

# %%
Seattle_Rain= Seattle_Rain.replace(to_replace ="Moderate", 
                 value ="2")

# %%
Seattle_Rain= Seattle_Rain.replace(to_replace ="Light", 
                 value ="1")

# %%
Seattle_Rain= Seattle_Rain.replace(to_replace ="Heavy", 
                 value ="3")

# %%
WA = weather_events[weather_events['State'] == 'WA']

# %%
WA_Rain = WA[WA['Type'] == 'Rain']

# %%
x = WA.ZipCode

# %%
Seattle_Rain['Severity'] = Seattle_Rain['Severity'].astype(int)

# %%
Seattle_Rain
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 2585051  W-2585414  Rain         1  2016-01-03 20:53:00  2016-01-03 21:37:00
# 2585053  W-2585416  Rain         1  2016-01-04 06:53:00  2016-01-04 07:35:00
# 2585054  W-2585417  Rain         1  2016-01-04 09:53:00  2016-01-04 10:53:00
# 2585055  W-2585418  Rain         1  2016-01-04 11:14:00  2016-01-04 18:53:00
# 2585058  W-2585421  Rain         1  2016-01-05 14:53:00  2016-01-05 18:53:00
# 2585059  W-2585422  Rain         1  2016-01-05 20:53:00  2016-01-06 02:53:00
# 2585060  W-2585423  Rain         1  2016-01-06 03:53:00  2016-01-06 06:53:00
# 2585066  W-2585429  Rain         1  2016-01-09 02:53:00  2016-01-09 03:53:00
# 2585073  W-2585436  Rain         1  2016-01-11 15:53:00  2016-01-11 17:53:00
# 2585074  W-2585437  Rain         1  2016-01-11 23:53:00  2016-01-12 03:53:00
# 2585075  W-2585438  Rain         1  2016-01-12 15:53:00  2016-01-13 06:53:00
# ...

# %%
Seattle_Rain['Month'] = pd.DatetimeIndex(Seattle_Rain['StartTime(UTC)']).month

# %%
Seattle_Rain['Year'] = pd.DatetimeIndex(Seattle_Rain['StartTime(UTC)']).year

# %%
Seattle_Rain['Day'] = pd.DatetimeIndex(Seattle_Rain['StartTime(UTC)']).day

# %%
Seattle_Rain['day_of_week'] = pd.DatetimeIndex(Seattle_Rain['StartTime(UTC)']).dayofweek

# %%
Seattle_Rain
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 2585051  W-2585414  Rain         1  2016-01-03 20:53:00  2016-01-03 21:37:00
# 2585053  W-2585416  Rain         1  2016-01-04 06:53:00  2016-01-04 07:35:00
# 2585054  W-2585417  Rain         1  2016-01-04 09:53:00  2016-01-04 10:53:00
# 2585055  W-2585418  Rain         1  2016-01-04 11:14:00  2016-01-04 18:53:00
# 2585058  W-2585421  Rain         1  2016-01-05 14:53:00  2016-01-05 18:53:00
# 2585059  W-2585422  Rain         1  2016-01-05 20:53:00  2016-01-06 02:53:00
# 2585060  W-2585423  Rain         1  2016-01-06 03:53:00  2016-01-06 06:53:00
# 2585066  W-2585429  Rain         1  2016-01-09 02:53:00  2016-01-09 03:53:00
# 2585073  W-2585436  Rain         1  2016-01-11 15:53:00  2016-01-11 17:53:00
# 2585074  W-2585437  Rain         1  2016-01-11 23:53:00  2016-01-12 03:53:00
# 2585075  W-2585438  Rain         1  2016-01-12 15:53:00  2016-01-13 06:53:00
# ...

# %%
sns.set(rc={'figure.figsize':(14,8.27)})
sns.catplot(x="day_of_week", y="Type", kind="swarm", data= Seattle_Rain);

# %%
Seattle_Rain.day_of_week.value_counts()
# Out:
# 4    643
# 3    605
# 6    545
# 5    541
# 2    517
# 1    489
# 0    442
# Name: day_of_week, dtype: int64

# %% [markdown]
# Seattle_Rain

# %%
Seattle_Rain['Severity'.value_counts.plot(x='')
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 2585051  W-2585414  Rain         1  2016-01-03 20:53:00  2016-01-03 21:37:00
# 2585053  W-2585416  Rain         1  2016-01-04 06:53:00  2016-01-04 07:35:00
# 2585054  W-2585417  Rain         1  2016-01-04 09:53:00  2016-01-04 10:53:00
# 2585055  W-2585418  Rain         1  2016-01-04 11:14:00  2016-01-04 18:53:00
# 2585058  W-2585421  Rain         1  2016-01-05 14:53:00  2016-01-05 18:53:00
# 2585059  W-2585422  Rain         1  2016-01-05 20:53:00  2016-01-06 02:53:00
# 2585060  W-2585423  Rain         1  2016-01-06 03:53:00  2016-01-06 06:53:00
# 2585066  W-2585429  Rain         1  2016-01-09 02:53:00  2016-01-09 03:53:00
# 2585073  W-2585436  Rain         1  2016-01-11 15:53:00  2016-01-11 17:53:00
# 2585074  W-2585437  Rain         1  2016-01-11 23:53:00  2016-01-12 03:53:00
# 2585075  W-2585438  Rain         1  2016-01-12 15:53:00  2016-01-13 06:53:00
# ...

# %%
Seattle_Light_Rain = Seattle_Rain['Severity'] == 1

# %%
Seattle_Light_Rain = Seattle_Rain[Seattle_Light_Rain]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-270-a2afa9157f24> in <module>
# ----> 1 Seattle_Light_Rain.Year.plot(x = 'Year').T
#
# AttributeError: 'AxesSubplot' object has no attribute 'T'
